# %%
import requests
from bs4 import BeautifulSoup
import re

r = requests.get("https://forum.gamer.com.tw/C.php?bsn=60076&snA=5866844&tnum=118")
soup = BeautifulSoup(r.text,"html.parser")
name = soup.select("div.reply-content a")
give = soup.select("article.reply-content__article.c-article span")

all = name+give

for i in all:
        if(i.text != ""):
            print(i.text)
        str = i.text
        m=re.compile("私") #編譯正規表示式，第一個引數是表示式字串，第二個引數是標誌位，比如re.I 匹配不對大小寫敏感，re.S等等
        result=m.findall(str) 
        #print(result)
        if(result):
            get = result
              
        if(i.text == "私"):
            print("------")
            print(i.text)
            
   
print(get)
# Out:
# 我宅故我在
# 先讓我想一下
# 黒羽紫音　無修正模式
# 黒羽紫音　無修正模式
# 鯊小
# ㄩㄌㄌ
# 方糖sugar
# 讓我看看
# 葬魂
# 陣頭小軒
# 寂靜子彈
# 世界第一蘿莉控
# 琴酒
# ∠( ᐛ 」∠)＿  yee
# G8貓
# 秦雨依
# 小強殺手
# Ried
# 雨夜
# 技巧第一
# 說來話長đ小超
# 1
# 冰楓
# 完美姆咪
# 某某魂
# 假如你生氣仰望耶穌❤
# ɐpnɯɐpnɯɐpnɯ
# 東條希a老公
# 6(AwA )
# 欠卡484
# 蛇蛇：
# [smile0445566:可以私嗎] ？
# [sakena:好耶] 度
# 這串有夠危險
# 我們休閒戰隊的飛龍只能活3分鐘 五王可以活好幾個小時
# [xyz19255:先拍一張-國標模式] 我婆一直都在陪我啊(´▽｀)
# 卡
# 泰瑞
# 美美也想加入~
# [TofuTM:洨豆腐] 好的感謝解答，這樣我大概知道怎麼抓尺度了
# 笑死 直接坐鎮
# 卡
# https://media.tenor.com/images/c7d504d9c6461995515026c2c95468ad/tenor.gif
# 怕...你各位都被盯著啊
# 2年前2年後都in爆
# 有關鍵字嗎
# 我打出來   會被車嗎？
# [cj6fu6:Ried]會
# 第一個有點久惹呢
# 噁心
# [jjjjj111:說來話長đ小超]怒https://i2.bahamut.com.tw/editor/emotion/14.gif
# [drummer0203:節能君] 姆咪寶...
# 自從海綿寶寶播出後永遠普級就不見了
# 健康教育課程可是非常普及的
# 好想知道第一張圖是哪部==
# 緣之空
# 綠之空
# ['私']

# %%
import re
str="abcdefabcdef" #待匹配的字串
m=re.compile("a") #編譯正規表示式，第一個引數是表示式字串，第二個引數是標誌位，比如re.I 匹配不對大小寫敏感，re.S等等
result=m.findall(str) 
print(result) #輸出["a","a"]
# Out:
# ['a', 'a']

# %%
import requests
from bs4 import BeautifulSoup
import re

r = requests.get("https://forum.gamer.com.tw/C.php?bsn=60076&snA=5866844&tnum=118")
soup = BeautifulSoup(r.text,"html.parser")
name = soup.select("div.reply-content a")
give = soup.select("article.reply-content__article.c-article span")

all = name+give
n =1
for i in name:
        if(i.text != ""):
            print(n,i.text)
            n += 1
        str = i.text
        m=re.compile("私") #編譯正規表示式，第一個引數是表示式字串，第二個引數是標誌位，比如re.I 匹配不對大小寫敏感，re.S等等
        result=m.findall(str) 
        #print(result)
        if(result):
            get = result
              
        if(i.text == "私"):
            print("------")
            print(i.text)
        
print("---------------------")
n =1
for i in give:
        if(i.text != ""):
            print(n,i.text)
            n +=1
        str = i.text
        m=re.compile("私") #編譯正規表示式，第一個引數是表示式字串，第二個引數是標誌位，比如re.I 匹配不對大小寫敏感，re.S等等
        result=m.findall(str) 
        #print(result)
        if(result):
            get = result
              
        if(i.text == "私"):
            print("------")
            print(i.text)
        
print("---------------------")   
print("總共有:",get)
# Out:
# 1 先讓我想一下
# 2 黒羽紫音　無修正模式
# 3 黒羽紫音　無修正模式
# 4 鯊小
# 5 臭酸的蛋糕
# 6 方糖sugar
# 7 讓我看看
# 8 葬魂
# 9 陣頭小軒
# 10 絕緣物
# 11 juest
# 12 ニューイヤーバースト
# 13 智乃
# 14 1
# 15 洨豆腐
# 16 洨豆腐
# 17 秦雨依
# 18 小強殺手
# 19 Ried
# 20 雨夜
# 21 技巧第一
# 22 說來話長đ小超
# 23 1
# 24 冰楓
# 25 完美姆咪
# 26 某某魂
# 27 假如你生氣仰望耶穌❤
# 28 ɐpnɯɐpnɯɐpnɯ
# 29 東條希a老公
# 30 6(AwA )
# ---------------------
# 1 蛇蛇：
# 2 [smile0445566:可以私嗎] ？
# 3 [sakena:好耶] 度
# 4 這串有夠危險
# 5 卡個研究用途 (X
# 6 [xyz19255:先拍一張-國標模式] 我婆一直都在陪我啊(´▽｀)
# 7 卡
# 8 泰瑞
# 9 美美也想加入~
# 10 貓
# 11 挖 太狂了吧
# 12 [TofuTM:洨豆腐] 如果同一頁本本 上半部純聊天無任何性行為、露點及激凸 下半部才有 只截圖上半部應該沒事?
# 13 [thunder0627:ニューイヤーバースト]你不講沒人知道阿..
# 14 [thunder0627:ニューイヤーバースト] 這要判斷是否在同一個圖框內，不是的話基本上不管
# 15 但是假設本來那個人上身裸露帶你只截上半身還是會管理
# 16 2年前2年後都in爆
# 17 有關鍵字嗎
# 18 我打出來   會被車嗎？
# 19 [cj6fu6:Ried]會
# 20 第一個有點久惹呢
# 21 噁心
# 22 [jjjjj111:說來話長đ小超]怒https://i2.bahamut.com.tw/editor/emotion/14.gif
# 23 [drummer0203:節能君] 姆咪寶...
# 24 自從海綿寶寶播出後永遠普級就不見了
# 25 健康教育課程可是非常普及的
# 26 好想知道第一張圖是哪部==
# 27 緣之空
# 28 綠之空
# ---------------------
# 總共有: ['私']

# %%
import requests
from bs4 import BeautifulSoup
import re
from selenium import webdriver

r = requests.get("https://forum.gamer.com.tw/C.php?bsn=60076&snA=5866844&tnum=118")
soup = BeautifulSoup(r.text,"html.parser")
check = soup.select("div.c-reply__head.nocontent a.more-reply")

On = soup.find("more-reply")
#部分代码
js="document.getElementsByClassName('login_btn')[1].style.display='block'"
driver.execute_script(js)
driver.find_element_by_xpath("//div[2][@class='login_btn']").click()
print(On)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-839c767ffe47> in <module>
#       2 from bs4 import BeautifulSoup
#       3 import re
# ----> 4 from selenium import webdriver
#       5
#       6 r = requests.get("https://forum.gamer.com.tw/C.php?bsn=60076&snA=5866844&tnum=118")
#
# ModuleNotFoundError: No module named 'selenium'
