# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
L = [4, 7, 8, 7, 9]

# %%
plot(L)

# %%
plot(randn(50))

# %%
L = [9, 70, 45, 2]
G = [2, 5, 7, 42]

# %%
L + G
# Out:
# [9, 70, 45, 2, 2, 5, 7, 42]

# %%
#沒有 L - G  list相減

# %%
L
# Out:
# [9, 70, 45, 2]

# %%
3 * L
# Out:
# [9, 70, 45, 2, 9, 70, 45, 2, 9, 70, 45, 2]
