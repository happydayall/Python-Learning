# %% [markdown]
# ## 使python能繪畫

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-2 , 8 , 4 , 7 , 9])  #(0,-2)(1,8)(2,4)(3,7)(4,9),依x值連接

# %%
randn(10) #平均值是10 標準差是1
# Out:
# array([-0.1671526 ,  0.52209073, -1.2053618 ,  0.62584116,  1.60961414,
#        -0.10936218,  2.06498301,  0.83655353, -1.38188407,  1.28647948])

# %%
plot(randn(100))  #100個點

# %%
plot([1.1 , 2.2 , 1.5 , 4.4 , 5.5],[5.1 , 4.2 , 5.1 , 2.4 , 1.5])  #可獨立標示x,y值
